# %% [markdown]
# # Grfns in Julia
#
# Here is an example of how to represent a grfn from https://github.com/ml4ai/delphi
# specifically http://vision.cs.arizona.edu/adarsh/Delphi-Demo-Notebook.html

# %%
using Pkg
Pkg.add(["JSON", "JSON2"])
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
using JSON
using JSON2

# %%
testgrfn = """{
"start": "CROP_YIELD",
"functions": [
  {
    "name": "UPDATE_EST__assign__TOTAL_RAIN_0",
    "type": "assign",
    "target": "TOTAL_RAIN",
    "sources": [
      "TOTAL_RAIN",
      "RAIN"
    ],
    "body": [
      {
        "type": "lambda",
        "name": "UPDATE_EST__lambda__TOTAL_RAIN_0",
        "reference": 4
      }
    ]
  },
  {
    "name": "UPDATE_EST__condition__IF_1_0",
    "type": "assign",
    "target": "IF_1",
    "sources": [
      "TOTAL_RAIN"
    ],
    "body": [
      {
        "type": "lambda",
        "name": "UPDATE_EST__lambda__IF_1_0",
        "reference": 5
      }
    ]
  },
  {
    "name": "UPDATE_EST__assign__YIELD_EST_0",
    "type": "assign",
    "target": "YIELD_EST",
    "sources": [
      "TOTAL_RAIN"
    ],
    "body": [
      {
        "type": "lambda",
        "name": "UPDATE_EST__lambda__YIELD_EST_0",
        "reference": 6
      }
    ]
  },
  {
    "name": "UPDATE_EST__assign__YIELD_EST_1",
    "type": "assign",
    "target": "YIELD_EST",
    "sources": [
      "TOTAL_RAIN"
    ],
    "body": [
      {
        "type": "lambda",
        "name": "UPDATE_EST__lambda__YIELD_EST_1",
        "reference": 8
      }
    ]
  },
  {
    "name": "UPDATE_EST__decision__YIELD_EST_0",
    "type": "assign",
    "target": "YIELD_EST",
    "sources": [
      "IF_1_0",
      "YIELD_EST_2",
      "YIELD_EST_1"
    ]
  },
  {
    "name": "UPDATE_EST",
    "type": "container",
    "input": [
      {
        "name": "RAIN",
        "domain": "real"
      },
      {
        "name": "TOTAL_RAIN",
        "domain": "real"
      },
      {
        "name": "YIELD_EST",
        "domain": "real"
      }
    ],
    "variables": [
      {
        "name": "TOTAL_RAIN",
        "domain": "real"
      },
      {
        "name": "RAIN",
        "domain": "real"
      },
      {
        "name": "IF_1",
        "domain": "boolean"
      },
      {
        "name": "YIELD_EST",
        "domain": "real"
      }
    ],
    "body": [
      {
        "name": "UPDATE_EST__assign__TOTAL_RAIN_0",
        "output": {
          "variable": "TOTAL_RAIN",
          "index": 1
        },
        "input": [
          {
            "variable": "TOTAL_RAIN",
            "index": 0
          },
          {
            "variable": "RAIN",
            "index": 0
          }
        ]
      },
      {
        "name": "UPDATE_EST__condition__IF_1_0",
        "output": {
          "variable": "IF_1",
          "index": 0
        },
        "input": [
          {
            "variable": "TOTAL_RAIN",
            "index": 1
          }
        ]
      },
      {
        "name": "UPDATE_EST__assign__YIELD_EST_0",
        "output": {
          "variable": "YIELD_EST",
          "index": 1
        },
        "input": [
          {
            "variable": "TOTAL_RAIN",
            "index": 1
          }
        ]
      },
      {
        "name": "UPDATE_EST__assign__YIELD_EST_1",
        "output": {
          "variable": "YIELD_EST",
          "index": 2
        },
        "input": [
          {
            "variable": "TOTAL_RAIN",
            "index": 1
          }
        ]
      },
      {
        "name": "UPDATE_EST__decision__YIELD_EST_0",
        "output": {
          "variable": "YIELD_EST",
          "index": 3
        },
        "input": [
          {
            "variable": "IF_1",
            "index": 0
          },
          {
            "variable": "YIELD_EST",
            "index": 2
          },
          {
            "variable": "YIELD_EST",
            "index": 1
          }
        ]
      }
    ]
  },
  {
    "name": "CROP_YIELD__assign__MAX_RAIN_0",
    "type": "assign",
    "target": "MAX_RAIN",
    "sources": [],
    "body": {
      "type": "literal",
      "dtype": "real",
      "value": "4.0"
    }
  },
  {
    "name": "CROP_YIELD__assign__CONSISTENCY_0",
    "type": "assign",
    "target": "CONSISTENCY",
    "sources": [],
    "body": {
      "type": "literal",
      "dtype": "real",
      "value": "64.0"
    }
  },
  {
    "name": "CROP_YIELD__assign__ABSORPTION_0",
    "type": "assign",
    "target": "ABSORPTION",
    "sources": [],
    "body": {
      "type": "literal",
      "dtype": "real",
      "value": "0.6"
    }
  },
  {
    "name": "CROP_YIELD__assign__YIELD_EST_0",
    "type": "assign",
    "target": "YIELD_EST",
    "sources": [],
    "body": {
      "type": "literal",
      "dtype": "integer",
      "value": "0"
    }
  },
  {
    "name": "CROP_YIELD__assign__TOTAL_RAIN_0",
    "type": "assign",
    "target": "TOTAL_RAIN",
    "sources": [],
    "body": {
      "type": "literal",
      "dtype": "integer",
      "value": "0"
    }
  },
  {
    "name": "CROP_YIELD__assign__RAIN_0",
    "type": "assign",
    "target": "RAIN",
    "sources": [
      "DAY",
      "CONSISTENCY",
      "MAX_RAIN",
      "ABSORPTION"
    ],
    "body": [
      {
        "type": "lambda",
        "name": "CROP_YIELD__lambda__RAIN_0",
        "reference": 24
      }
    ]
  },
  {
    "name": "CROP_YIELD__loop_plate__DAY_0",
    "type": "loop_plate",
    "input": [
      "CONSISTENCY",
      "MAX_RAIN",
      "ABSORPTION",
      "RAIN",
      "TOTAL_RAIN",
      "YIELD_EST"
    ],
    "index_variable": "DAY",
    "index_iteration_range": {
      "start": {
        "type": "literal",
        "dtype": "integer",
        "value": 1
      },
      "end": {
        "value": 32,
        "dtype": "integer",
        "type": "literal"
      }
    },
    "body": [
      {
        "name": "CROP_YIELD__assign__RAIN_0",
        "output": {
          "variable": "RAIN",
          "index": 0
        },
        "input": [
          {
            "variable": "DAY",
            "index": -1
          },
          {
            "variable": "CONSISTENCY",
            "index": -1
          },
          {
            "variable": "MAX_RAIN",
            "index": -1
          },
          {
            "variable": "ABSORPTION",
            "index": -1
          }
        ]
      },
      {
        "function": "UPDATE_EST",
        "output": {},
        "input": [
          {
            "variable": "RAIN",
            "index": 0
          },
          {
            "variable": "TOTAL_RAIN",
            "index": -1
          },
          {
            "variable": "YIELD_EST",
            "index": -1
          }
        ]
      },
      {
        "function": "print",
        "output": {},
        "input": [
          {
            "variable": "DAY",
            "index": -1
          },
          {
            "variable": "YIELD_EST",
            "index": -1
          }
        ]
      }
    ]
  },
  {
    "name": "CROP_YIELD",
    "type": "container",
    "input": [],
    "variables": [
      {
        "name": "DAY",
        "domain": "integer"
      },
      {
        "name": "RAIN",
        "domain": "real"
      },
      {
        "name": "YIELD_EST",
        "domain": "real"
      },
      {
        "name": "TOTAL_RAIN",
        "domain": "real"
      },
      {
        "name": "MAX_RAIN",
        "domain": "real"
      },
      {
        "name": "CONSISTENCY",
        "domain": "real"
      },
      {
        "name": "ABSORPTION",
        "domain": "real"
      }
    ],
    "body": [
      {
        "name": "CROP_YIELD__assign__MAX_RAIN_0",
        "output": {
          "variable": "MAX_RAIN",
          "index": 2
        },
        "input": []
      },
      {
        "name": "CROP_YIELD__assign__CONSISTENCY_0",
        "output": {
          "variable": "CONSISTENCY",
          "index": 2
        },
        "input": []
      },
      {
        "name": "CROP_YIELD__assign__ABSORPTION_0",
        "output": {
          "variable": "ABSORPTION",
          "index": 2
        },
        "input": []
      },
      {
        "name": "CROP_YIELD__assign__YIELD_EST_0",
        "output": {
          "variable": "YIELD_EST",
          "index": 2
        },
        "input": []
      },
      {
        "name": "CROP_YIELD__assign__TOTAL_RAIN_0",
        "output": {
          "variable": "TOTAL_RAIN",
          "index": 2
        },
        "input": []
      },
      {
        "name": "CROP_YIELD__loop_plate__DAY_0",
        "inputs": [
          "CONSISTENCY",
          "MAX_RAIN",
          "ABSORPTION",
          "RAIN",
          "TOTAL_RAIN",
          "YIELD_EST"
        ],
        "output": {}
      },
      {
        "function": "print",
        "output": {},
        "input": [
          {
            "variable": "YIELD_EST",
            "index": 2
          }
        ]
      }
    ]
  }
],
"name": "pgm.json",
"dateCreated": "2018-10-04"
}
"""
# Out:
# "{\n\"start\": \"CROP_YIELD\",\n\"functions\": [\n  {\n    \"name\": \"UPDATE_EST__assign__TOTAL_RAIN_0\",\n    \"type\": \"assign\",\n    \"target\": \"TOTAL_RAIN\",\n    \"sources\": [\n      \"TOTAL_RAIN\",\n      \"RAIN\"\n    ],\n    \"body\": [\n      {\n        \"type\": \"lambda\",\n        \"name\": \"UPDATE_EST__lambda__TOTAL_RAIN_0\",\n        \"reference\": 4\n      }\n    ]\n  },\n  {\n    \"name\": \"UPDATE_EST__condition__IF_1_0\",\n    \"type\": \"assign\",\n    \"target\": \"IF_1\",\n    \"sources\": [\n      \"TOTAL_RAIN\"\n    ],\n    \"body\": [\n      {\n        \"type\": \"lambda\",\n        \"name\": \"UPDATE_EST__lambda__IF_1_0\",\n        \"reference\": 5\n      }\n    ]\n  },\n  {\n    \"name\": \"UPDATE_EST__assign__YIELD_EST_0\",\n    \"type\": \"assign\",\n    \"target\": \"YIELD_EST\",\n    \"sources\": [\n      \"TOTAL_RAIN\"\n    ],\n    \"body\": [\n      {\n        \"type\": \"lambda\",\n        \"name\": \"UPDATE_EST__lambda__YIELD_EST_0\",\n        \"reference\": 6\n      }\n    ]\n  },\n  {\n    \"name\": \"UPDATE_EST__assign__YIELD_EST_1\",\n    \"type\": \"assign\",\n    \"target\": \"YIELD_EST\",\n    \"sources\": [\n      \"TOTAL_RAIN\"\n    ],\n    \"body\": [\n      {\n        \"type\": \"lambda\",\n        \"name\": \"UPDATE_EST__lambda__YIELD_EST_1\",\n        \"reference\": 8\n      }\n    ]\n  },\n  {\n    \"name\": \"UPDATE_EST__decision__YIELD_EST_0\",\n    \"type\": \"assign\",\n    \"target\": \"YIELD_EST\",\n    \"sources\": [\n      \"IF_1_0\",\n      \"YIELD_EST_2\",\n      \"YIELD_EST_1\"\n    ]\n  },\n  {\n    \"name\": \"UPDATE_EST\",\n    \"type\": \"container\",\n    \"input\": [\n      {\n        \"name\": \"RAIN\",\n        \"domain\": \"real\"\n      },\n      {\n        \"name\": \"TOTAL_RAIN\",\n        \"domain\": \"real\"\n      },\n      {\n        \"name\": \"YIELD_EST\",\n        \"domain\": \"real\"\n      }\n    ],\n    \"variables\": [\n      {\n        \"name\": \"TOTAL_RAIN\",\n        \"domain\": \"real\"\n      },\n      {\n        \"name\": \"RAIN\",\n        \"domain\": \"real\"\n      },\n      {\n        \"name\": \"IF_1\",\n        \"domain\": \"boolean\"\n      },\n      {\n        \"name\": \"YIELD_EST\",\n        \"domain\": \"real\"\n      }\n    ],\n    \"body\": [\n      {\n        \"name\": \"UPDATE_EST__assign__TOTAL_RAIN_0\",\n        \"output\": {\n          \"variable\": \"TOTAL_RAIN\",\n          \"index\": 1\n        },\n        \"input\": [\n          {\n            \"variable\": \"TOTAL_RAIN\",\n            \"index\": 0\n          },\n          {\n            \"variable\": \"RAIN\",\n            \"index\": 0\n          }\n        ]\n      },\n      {\n        \"name\": \"UPDATE_EST__condition__IF_1_0\",\n        \"output\": {\n          \"variable\": \"IF_1\",\n          \"index\": 0\n        },\n        \"input\": [\n          {\n            \"variable\": \"TOTAL_RAIN\",\n            \"index\": 1\n          }\n        ]\n      },\n      {\n        \"name\": \"UPDATE_EST__assign__YIELD_EST_0\",\n        \"output\": {\n          \"variable\": \"YIELD_EST\",\n          \"index\": 1\n        },\n        \"input\": [\n          {\n            \"variable\": \"TOTAL_RAIN\",\n            \"index\": 1\n          }\n        ]\n      },\n      {\n        \"name\": \"UPDATE_EST__assign__YIELD_EST_1\",\n        \"output\": {\n          \"variable\": \"YIELD_EST\",\n          \"index\": 2\n        },\n        \"input\": [\n          {\n            \"variable\": \"TOTAL_RAIN\",\n            \"index\": 1\n          }\n        ]\n      },\n      {\n        \"name\": \"UPDATE_EST__decision__YIELD_EST_0\",\n        \"output\": {\n          \"variable\": \"YIELD_EST\",\n          \"index\": 3\n        },\n        \"input\": [\n          {\n            \"variable\": \"IF_1\",\n            \"index\": 0\n          },\n          {\n            \"variable\": \"YIELD_EST\",\n            \"index\": 2\n          },\n          {\n            \"variable\": \"YI ...

# %%
obj = JSON.parse(testgrfn)
# Out:
# Dict{String,Any} with 4 entries:
#   "name"        => "pgm.json"
#   "start"       => "CROP_YIELD"
#   "dateCreated" => "2018-10-04"
#   "functions"   => Any[Dict{String,Any}("name"=>"UPDATE_EST__assign__TOTAL_RAIN…

# %%
module GrfnMod

mutable struct Grfn{D,T}
    name::String
    start::String
    created::D
    functions::T
end
struct Input
    name::String
    domain::String
end

struct Container{I,V,B}
    name::String
    type::String
    input::I
    variables::V
    body::B
end
Container(tuple) = Container(tuple...)

mutable struct GrfnBody{S,T,U}
    name::S
    type::T
    reference::U
end

mutable struct GrfnSource{S}
    name::S
end
    
mutable struct GrfnNode{T,U,V}
    name::String
    type::T
    target::String
    sources::V
    body::U
end
#GrfnSource(x::NamedTuple) = GrfnSource(x...)
GrfnBody(x::NamedTuple) = GrfnBody(x...)
# GrfnNode(n,t,r,s::Vector{Any},b::Vector{Any}) = begin
#     GrfnNode(n,t,r,GrfnSource.(s), GrfnBody.(b))
# end
struct Assignment{T,U}
    name::String
    typ::String
    target::String
    sources::T
    body::U
end
function Assignment(n,t,r,s)
    return Assignment(n,t,r,s,Missing)
end

function Assignment(tuple::NamedTuple)
    print(tuple)
    return Assignment(tuple...)
end

struct LoopPlate{I,T,R,B}
    name::String
    type::String
    input::I
    index_variable::T
    index_iteration_range::R
    body::B                
end
LoopPlate(t::NamedTuple) = LoopPlate(t...)
end
# Out:
# WARNING: replacing module GrfnMod.
# Main.GrfnMod

# %%
GrfnMod.Grfn(obj["name"], obj["start"], obj["dateCreated"], obj["functions"])
# Out:
# Main.GrfnMod.Grfn{String,Array{Any,1}}("pgm.json", "CROP_YIELD", "2018-10-04", Any[Dict{String,Any}("name"=>"UPDATE_EST__assign__TOTAL_RAIN_0","body"=>Any[Dict{String,Any}("name"=>"UPDATE_EST__lambda__TOTAL_RAIN_0","reference"=>4,"type"=>"lambda")],"target"=>"TOTAL_RAIN","sources"=>Any["TOTAL_RAIN", "RAIN"],"type"=>"assign"), Dict{String,Any}("name"=>"UPDATE_EST__condition__IF_1_0","body"=>Any[Dict{String,Any}("name"=>"UPDATE_EST__lambda__IF_1_0","reference"=>5,"type"=>"lambda")],"target"=>"IF_1","sources"=>Any["TOTAL_RAIN"],"type"=>"assign"), Dict{String,Any}("name"=>"UPDATE_EST__assign__YIELD_EST_0","body"=>Any[Dict{String,Any}("name"=>"UPDATE_EST__lambda__YIELD_EST_0","reference"=>6,"type"=>"lambda")],"target"=>"YIELD_EST","sources"=>Any["TOTAL_RAIN"],"type"=>"assign"), Dict{String,Any}("name"=>"UPDATE_EST__assign__YIELD_EST_1","body"=>Any[Dict{String,Any}("name"=>"UPDATE_EST__lambda__YIELD_EST_1","reference"=>8,"type"=>"lambda")],"target"=>"YIELD_EST","sources"=>Any["TOTAL_RAIN"],"type"=>"assign"), Dict{String,Any}("name"=>"UPDATE_EST__decision__YIELD_EST_0","target"=>"YIELD_EST","sources"=>Any["IF_1_0", "YIELD_EST_2", "YIELD_EST_1"],"type"=>"assign"), Dict{String,Any}("name"=>"UPDATE_EST","body"=>Any[Dict{String,Any}("name"=>"UPDATE_EST__assign__TOTAL_RAIN_0","output"=>Dict{String,Any}("variable"=>"TOTAL_RAIN","index"=>1),"input"=>Any[Dict{String,Any}("variable"=>"TOTAL_RAIN","index"=>0), Dict{String,Any}("variable"=>"RAIN","index"=>0)]), Dict{String,Any}("name"=>"UPDATE_EST__condition__IF_1_0","output"=>Dict{String,Any}("variable"=>"IF_1","index"=>0),"input"=>Any[Dict{String,Any}("variable"=>"TOTAL_RAIN","index"=>1)]), Dict{String,Any}("name"=>"UPDATE_EST__assign__YIELD_EST_0","output"=>Dict{String,Any}("variable"=>"YIELD_EST","index"=>1),"input"=>Any[Dict{String,Any}("variable"=>"TOTAL_RAIN","index"=>1)]), Dict{String,Any}("name"=>"UPDATE_EST__assign__YIELD_EST_1","output"=>Dict{String,Any}("variable"=>"YIELD_EST","index"=>2),"input"=>Any[Dict{String,Any}("variable"=>"TOTAL_RAIN","index"=>1)]), Dict{String,Any}("name"=>"UPDATE_EST__decision__YIELD_EST_0","output"=>Dict{String,Any}("variable"=>"YIELD_EST","index"=>3),"input"=>Any[Dict{String,Any}("variable"=>"IF_1","index"=>0), Dict{String,Any}("variable"=>"YIELD_EST","index"=>2), Dict{String,Any}("variable"=>"YIELD_EST","index"=>1)])],"variables"=>Any[Dict{String,Any}("name"=>"TOTAL_RAIN","domain"=>"real"), Dict{String,Any}("name"=>"RAIN","domain"=>"real"), Dict{String,Any}("name"=>"IF_1","domain"=>"boolean"), Dict{String,Any}("name"=>"YIELD_EST","domain"=>"real")],"input"=>Any[Dict{String,Any}("name"=>"RAIN","domain"=>"real"), Dict{String,Any}("name"=>"TOTAL_RAIN","domain"=>"real"), Dict{String,Any}("name"=>"YIELD_EST","domain"=>"real")],"type"=>"container"), Dict{String,Any}("name"=>"CROP_YIELD__assign__MAX_RAIN_0","body"=>Dict{String,Any}("dtype"=>"real","value"=>"4.0","type"=>"literal"),"target"=>"MAX_RAIN","sources"=>Any[],"type"=>"assign"), Dict{String,Any}("name"=>"CROP_YIELD__assign__CONSISTENCY_0","body"=>Dict{String,Any}("dtype"=>"real","value"=>"64.0","type"=>"literal"),"target"=>"CONSISTENCY","sources"=>Any[],"type"=>"assign"), Dict{String,Any}("name"=>"CROP_YIELD__assign__ABSORPTION_0","body"=>Dict{String,Any}("dtype"=>"real","value"=>"0.6","type"=>"literal"),"target"=>"ABSORPTION","sources"=>Any[],"type"=>"assign"), Dict{String,Any}("name"=>"CROP_YIELD__assign__YIELD_EST_0","body"=>Dict{String,Any}("dtype"=>"integer","value"=>"0","type"=>"literal"),"target"=>"YIELD_EST","sources"=>Any[],"type"=>"assign"), Dict{String,Any}("name"=>"CROP_YIELD__assign__TOTAL_RAIN_0","body"=>Dict{String,Any}("dtype"=>"integer","value"=>"0","type"=>"literal"),"target"=>"TOTAL_RAIN","sources"=>Any[],"type"=>"assign"), Dict{String,Any}("name"=>"CROP_YIELD__assign__RAIN_0","body"=>Any[Dict{String,Any}("name"=>"CROP_YIELD__lambda__RAIN_0","reference"=>24,"type"=>"lambda")],"target"=>"RAIN","sources"=>Any["DAY", "CONSISTENCY", "MAX_RAIN", "ABSORPTION"],"type"=>"assign"), Dict{Strin ...

# %%
sobj = JSON2.read(testgrfn)
# Out:
# (start = "CROP_YIELD", functions = Any[(name = "UPDATE_EST__assign__TOTAL_RAIN_0", type = "assign", target = "TOTAL_RAIN", sources = Any["TOTAL_RAIN", "RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__TOTAL_RAIN_0", reference = 4)]), (name = "UPDATE_EST__condition__IF_1_0", type = "assign", target = "IF_1", sources = Any["TOTAL_RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__IF_1_0", reference = 5)]), (name = "UPDATE_EST__assign__YIELD_EST_0", type = "assign", target = "YIELD_EST", sources = Any["TOTAL_RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_0", reference = 6)]), (name = "UPDATE_EST__assign__YIELD_EST_1", type = "assign", target = "YIELD_EST", sources = Any["TOTAL_RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_1", reference = 8)]), (name = "UPDATE_EST__decision__YIELD_EST_0", type = "assign", target = "YIELD_EST", sources = Any["IF_1_0", "YIELD_EST_2", "YIELD_EST_1"]), (name = "UPDATE_EST", type = "container", input = Any[(name = "RAIN", domain = "real"), (name = "TOTAL_RAIN", domain = "real"), (name = "YIELD_EST", domain = "real")], variables = Any[(name = "TOTAL_RAIN", domain = "real"), (name = "RAIN", domain = "real"), (name = "IF_1", domain = "boolean"), (name = "YIELD_EST", domain = "real")], body = Any[(name = "UPDATE_EST__assign__TOTAL_RAIN_0", output = (variable = "TOTAL_RAIN", index = 1), input = Any[(variable = "TOTAL_RAIN", index = 0), (variable = "RAIN", index = 0)]), (name = "UPDATE_EST__condition__IF_1_0", output = (variable = "IF_1", index = 0), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__assign__YIELD_EST_0", output = (variable = "YIELD_EST", index = 1), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__assign__YIELD_EST_1", output = (variable = "YIELD_EST", index = 2), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__decision__YIELD_EST_0", output = (variable = "YIELD_EST", index = 3), input = Any[(variable = "IF_1", index = 0), (variable = "YIELD_EST", index = 2), (variable = "YIELD_EST", index = 1)])]), (name = "CROP_YIELD__assign__MAX_RAIN_0", type = "assign", target = "MAX_RAIN", sources = Any[], body = (type = "literal", dtype = "real", value = "4.0")), (name = "CROP_YIELD__assign__CONSISTENCY_0", type = "assign", target = "CONSISTENCY", sources = Any[], body = (type = "literal", dtype = "real", value = "64.0")), (name = "CROP_YIELD__assign__ABSORPTION_0", type = "assign", target = "ABSORPTION", sources = Any[], body = (type = "literal", dtype = "real", value = "0.6")), (name = "CROP_YIELD__assign__YIELD_EST_0", type = "assign", target = "YIELD_EST", sources = Any[], body = (type = "literal", dtype = "integer", value = "0")), (name = "CROP_YIELD__assign__TOTAL_RAIN_0", type = "assign", target = "TOTAL_RAIN", sources = Any[], body = (type = "literal", dtype = "integer", value = "0")), (name = "CROP_YIELD__assign__RAIN_0", type = "assign", target = "RAIN", sources = Any["DAY", "CONSISTENCY", "MAX_RAIN", "ABSORPTION"], body = Any[(type = "lambda", name = "CROP_YIELD__lambda__RAIN_0", reference = 24)]), (name = "CROP_YIELD__loop_plate__DAY_0", type = "loop_plate", input = Any["CONSISTENCY", "MAX_RAIN", "ABSORPTION", "RAIN", "TOTAL_RAIN", "YIELD_EST"], index_variable = "DAY", index_iteration_range = (start = (type = "literal", dtype = "integer", value = 1), end = (value = 32, dtype = "integer", type = "literal")), body = Any[(name = "CROP_YIELD__assign__RAIN_0", output = (variable = "RAIN", index = 0), input = Any[(variable = "DAY", index = -1), (variable = "CONSISTENCY", index = -1), (variable = "MAX_RAIN", index = -1), (variable = "ABSORPTION", index = -1)]), (function = "UPDATE_EST", output = NamedTuple(), input = Any[(variable = "RAIN", index = 0), (variable = "TOTAL_RAIN", index = -1), (variable = "YIELD_EST", index = -1)]), (function = "print", output = NamedTuple(), input = Any[(variable = "DAY", index = -1), (variable = "YIELD_EST",  ...

# %%
sobj.start
# Out:
# "CROP_YIELD"

# %%
sobj.functions
# Out:
# 14-element Array{Any,1}:
#  (name = "UPDATE_EST__assign__TOTAL_RAIN_0", type = "assign", target = "TOTAL_RAIN", sources = Any["TOTAL_RAIN", "RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__TOTAL_RAIN_0", reference = 4)])
#  (name = "UPDATE_EST__condition__IF_1_0", type = "assign", target = "IF_1", sources = Any["TOTAL_RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__IF_1_0", reference = 5)])
#  (name = "UPDATE_EST__assign__YIELD_EST_0", type = "assign", target = "YIELD_EST", sources = Any["TOTAL_RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_0", reference = 6)])
#  (name = "UPDATE_EST__assign__YIELD_EST_1", type = "assign", target = "YIELD_EST", sources = Any["TOTAL_RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_1", reference = 8)])
#  (name = "UPDATE_EST__decision__YIELD_EST_0", type = "assign", target = "YIELD_EST", sources = Any["IF_1_0", "YIELD_EST_2", "YIELD_EST_1"])
#  (name = "UPDATE_EST", type = "container", input = Any[(name = "RAIN", domain = "real"), (name = "TOTAL_RAIN", domain = "real"), (name = "YIELD_EST", domain = "real")], variables = Any[(name = "TOTAL_RAIN", domain = "real"), (name = "RAIN", domain = "real"), (name = "IF_1", domain = "boolean"), (name = "YIELD_EST", domain = "real")], body = Any[(name = "UPDATE_EST__assign__TOTAL_RAIN_0", output = (variable = "TOTAL_RAIN", index = 1), input = Any[(variable = "TOTAL_RAIN", index = 0), (variable = "RAIN", index = 0)]), (name = "UPDATE_EST__condition__IF_1_0", output = (variable = "IF_1", index = 0), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__assign__YIELD_EST_0", output = (variable = "YIELD_EST", index = 1), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__assign__YIELD_EST_1", output = (variable = "YIELD_EST", index = 2), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__decision__YIELD_EST_0", output = (variable = "YIELD_EST", index = 3), input = Any[(variable = "IF_1", index = 0), (variable = "YIELD_EST", index = 2), (variable = "YIELD_EST", index = 1)])])
#  (name = "CROP_YIELD__assign__MAX_RAIN_0", type = "assign", target = "MAX_RAIN", sources = Any[], body = (type = "literal", dtype = "real", value = "4.0"))
#  (name = "CROP_YIELD__assign__CONSISTENCY_0", type = "assign", target = "CONSISTENCY", sources = Any[], body = (type = "literal", dtype = "real", value = "64.0"))
#  (name = "CROP_YIELD__assign__ABSORPTION_0", type = "assign", target = "ABSORPTION", sources = Any[], body = (type = "literal", dtype = "real", value = "0.6"))
#  (name = "CROP_YIELD__assign__YIELD_EST_0", type = "assign", target = "YIELD_EST", sources = Any[], body = (type = "literal", dtype = "integer", value = "0"))
#  (name = "CROP_YIELD__assign__TOTAL_RAIN_0", type = "assign", target = "TOTAL_RAIN", sources = Any[], body = (type = "literal", dtype = "integer", value = "0"))
#  (name = "CROP_YIELD__assign__RAIN_0", type = "assign", target = "RAIN", sources = Any["DAY", "CONSISTENCY", "MAX_RAIN", "ABSORPTION"], body = Any[(type = "lambda", name = "CROP_YIELD__lambda__RAIN_0", reference = 24)])
#  (name = "CROP_YIELD__loop_plate__DAY_0", type = "loop_plate", input = Any["CONSISTENCY", "MAX_RAIN", "ABSORPTION", "RAIN", "TOTAL_RAIN", "YIELD_EST"], index_variable = "DAY", index_iteration_range = (start = (type = "literal", dtype = "integer", value = 1), end = (value = 32, dtype = "integer", type = "literal")), body = Any[(name = "CROP_YIELD__assign__RAIN_0", output = (variable = "RAIN", index = 0), input = Any[(variable = "DAY", index = -1), (variable = "CONSISTENCY", index = -1), (variable = "MAX_RAIN", index = -1), (variable = "ABSORPTION", index = -1)]), (function = "UPDATE_EST", output = NamedTuple(), input = Any[(variable = "RAIN", index = 0), (variable = "TOTAL_RAIN", index = -1), (variable = "YIELD_EST", index = -1)]), (function = "print", output = NamedTuple(), input = Any[(variable = "DAY", index = -1), (variable = "YIELD_EST", index = -1)])])
#  (name = "CROP_YIELD", type = "container", input = Any[], variables = Any[(name = "DAY", domain = "integer"), (name = "RAIN", domain = "real"), (name = "YIELD_EST", domain = "real"), (name = "TOTAL_RAIN", domain = "real"), (name = "MAX_RAIN", domain = "real"), (name = "CONSISTENCY", domain = "real"), (name = "ABSORPTION", domain = "real")], body = Any[(name = "CROP_YIELD__assign__MAX_RAIN_0", output = (variable = "MAX_RAIN", index = 2), input = Any[]), (name = "CROP_YIELD__assign__CONSISTENCY_0", output = (variable = "CONSISTENCY", index = 2), input = Any[]), (name = "CROP_YIELD__assign__ABSORPTION_0", output = (variable = "ABSORPTION", index = 2), input = Any[]), (name = "CROP_YIELD__assign__YIELD_EST_0", output = (variable = "YIELD_EST", index = 2), input = Any[]), (name = "CROP_YIELD__assign__TOTAL_RAIN_0", output = (variable = "TOTAL_RAIN", index = 2), input = Any[]), (name = "CROP_YIELD__loop_plate__DAY_0", inputs = Any["CONSISTENCY", "MAX_RAIN", "ABSORPTION", "RAIN", "TOTAL_RAIN", "YIELD_EST"], output = NamedTuple()), (function = "print", output = NamedTuple(), input = Any[(variable = "YIELD_EST", index = 2)])])

# %%
@show sobj.name
@show sobj.dateCreated
@show sobj.start

nodes = []
for func in sobj.functions
    println("========================")
    if func.type == "assign"
      node = GrfnMod.Assignment(func)
    elseif func.type == "container"
      println("Found a Container Node")
      node = GrfnMod.Container(func)
    elseif func.type == "loop_plate"
      println("Found a LoopPlate Node")
      node = GrfnMod.LoopPlate(func)
    else
      dump(func)
    end
    push!(nodes, node)
    println("------------------------")
end
# Out:
# sobj.name = "pgm.json"
# sobj.dateCreated = "2018-10-04"
# sobj.start = "CROP_YIELD"
# ========================
# (name = "UPDATE_EST__assign__TOTAL_RAIN_0", type = "assign", target = "TOTAL_RAIN", sources = Any["TOTAL_RAIN", "RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__TOTAL_RAIN_0", reference = 4)])------------------------
# ========================
# (name = "UPDATE_EST__condition__IF_1_0", type = "assign", target = "IF_1", sources = Any["TOTAL_RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__IF_1_0", reference = 5)])------------------------
# ========================
# (name = "UPDATE_EST__assign__YIELD_EST_0", type = "assign", target = "YIELD_EST", sources = Any["TOTAL_RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_0", reference = 6)])------------------------
# ========================
# (name = "UPDATE_EST__assign__YIELD_EST_1", type = "assign", target = "YIELD_EST", sources = Any["TOTAL_RAIN"], body = Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_1", reference = 8)])------------------------
# ========================
# (name = "UPDATE_EST__decision__YIELD_EST_0", type = "assign", target = "YIELD_EST", sources = Any["IF_1_0", "YIELD_EST_2", "YIELD_EST_1"])------------------------
# ========================
# Found a Container Node
# ------------------------
# ========================
# (name = "CROP_YIELD__assign__MAX_RAIN_0", type = "assign", target = "MAX_RAIN", sources = Any[], body = (type = "literal", dtype = "real", value = "4.0"))------------------------
# ========================
# (name = "CROP_YIELD__assign__CONSISTENCY_0", type = "assign", target = "CONSISTENCY", sources = Any[], body = (type = "literal", dtype = "real", value = "64.0"))------------------------
# ========================
# (name = "CROP_YIELD__assign__ABSORPTION_0", type = "assign", target = "ABSORPTION", sources = Any[], body = (type = "literal", dtype = "real", value = "0.6"))------------------------
# ========================
# (name = "CROP_YIELD__assign__YIELD_EST_0", type = "assign", target = "YIELD_EST", sources = Any[], body = (type = "literal", dtype = "integer", value = "0"))------------------------
# ========================
# (name = "CROP_YIELD__assign__TOTAL_RAIN_0", type = "assign", target = "TOTAL_RAIN", sources = Any[], body = (type = "literal", dtype = "integer", value = "0"))------------------------
# ========================
# (name = "CROP_YIELD__assign__RAIN_0", type = "assign", target = "RAIN", sources = Any["DAY", "CONSISTENCY", "MAX_RAIN", "ABSORPTION"], body = Any[(type = "lambda", name = "CROP_YIELD__lambda__RAIN_0", reference = 24)])------------------------
# ========================
# Found a LoopPlate Node
# ------------------------
# ========================
# Found a Container Node
# ------------------------

# %%
g = GrfnMod.Grfn(sobj.name, sobj.dateCreated, sobj.start, nodes)
# Out:
# Main.GrfnMod.Grfn{String,Array{Any,1}}("pgm.json", "2018-10-04", "CROP_YIELD", Any[Assignment{Array{Any,1},Array{Any,1}}("UPDATE_EST__assign__TOTAL_RAIN_0", "assign", "TOTAL_RAIN", Any["TOTAL_RAIN", "RAIN"], Any[(type = "lambda", name = "UPDATE_EST__lambda__TOTAL_RAIN_0", reference = 4)]), Assignment{Array{Any,1},Array{Any,1}}("UPDATE_EST__condition__IF_1_0", "assign", "IF_1", Any["TOTAL_RAIN"], Any[(type = "lambda", name = "UPDATE_EST__lambda__IF_1_0", reference = 5)]), Assignment{Array{Any,1},Array{Any,1}}("UPDATE_EST__assign__YIELD_EST_0", "assign", "YIELD_EST", Any["TOTAL_RAIN"], Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_0", reference = 6)]), Assignment{Array{Any,1},Array{Any,1}}("UPDATE_EST__assign__YIELD_EST_1", "assign", "YIELD_EST", Any["TOTAL_RAIN"], Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_1", reference = 8)]), Assignment{Array{Any,1},DataType}("UPDATE_EST__decision__YIELD_EST_0", "assign", "YIELD_EST", Any["IF_1_0", "YIELD_EST_2", "YIELD_EST_1"], Missing), Container{Array{Any,1},Array{Any,1},Array{Any,1}}("UPDATE_EST", "container", Any[(name = "RAIN", domain = "real"), (name = "TOTAL_RAIN", domain = "real"), (name = "YIELD_EST", domain = "real")], Any[(name = "TOTAL_RAIN", domain = "real"), (name = "RAIN", domain = "real"), (name = "IF_1", domain = "boolean"), (name = "YIELD_EST", domain = "real")], Any[(name = "UPDATE_EST__assign__TOTAL_RAIN_0", output = (variable = "TOTAL_RAIN", index = 1), input = Any[(variable = "TOTAL_RAIN", index = 0), (variable = "RAIN", index = 0)]), (name = "UPDATE_EST__condition__IF_1_0", output = (variable = "IF_1", index = 0), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__assign__YIELD_EST_0", output = (variable = "YIELD_EST", index = 1), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__assign__YIELD_EST_1", output = (variable = "YIELD_EST", index = 2), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__decision__YIELD_EST_0", output = (variable = "YIELD_EST", index = 3), input = Any[(variable = "IF_1", index = 0), (variable = "YIELD_EST", index = 2), (variable = "YIELD_EST", index = 1)])]), Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__MAX_RAIN_0", "assign", "MAX_RAIN", Any[], (type = "literal", dtype = "real", value = "4.0")), Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__CONSISTENCY_0", "assign", "CONSISTENCY", Any[], (type = "literal", dtype = "real", value = "64.0")), Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__ABSORPTION_0", "assign", "ABSORPTION", Any[], (type = "literal", dtype = "real", value = "0.6")), Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__YIELD_EST_0", "assign", "YIELD_EST", Any[], (type = "literal", dtype = "integer", value = "0")), Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__TOTAL_RAIN_0", "assign", "TOTAL_RAIN", Any[], (type = "literal", dtype = "integer", value = "0")), Assignment{Array{Any,1},Array{Any,1}}("CROP_YIELD__assign__RAIN_0", "assign", "RAIN", Any["DAY", "CONSISTENCY", "MAX_RAIN", "ABSORPTION"], Any[(type = "lambda", name = "CROP_YIELD__lambda__RAIN_0", reference = 24)]), LoopPlate{Array{Any,1},String,NamedTuple{(:start, :end),Tuple{NamedTuple{(:type, :dtype, :value),Tuple{String,String,Int64}},NamedTuple{(:value, :dtype, :type),Tuple{Int64,String,String}}}},Array{Any,1}}("CROP_YIELD__loop_plate__DAY_0", "loop_plate", Any["CONSISTENCY", "MAX_RAIN", "ABSORPTION", "RAIN", "TOTAL_RAIN", "YIELD_EST"], "DAY", (start = (type = "literal", dtype = "integer", value = 1), end = (value = 32, dtype = "integer", type = "literal")), Any[(name = "CROP_YIELD__assign__RAIN_0", output = (variable = "RAIN", index = 0), input = Any[(variable = "DAY ...

# %%
for n in g.functions
    println(n)
    println()
end
# Out:
# Main.GrfnMod.Assignment{Array{Any,1},Array{Any,1}}("UPDATE_EST__assign__TOTAL_RAIN_0", "assign", "TOTAL_RAIN", Any["TOTAL_RAIN", "RAIN"], Any[(type = "lambda", name = "UPDATE_EST__lambda__TOTAL_RAIN_0", reference = 4)])
#
# Main.GrfnMod.Assignment{Array{Any,1},Array{Any,1}}("UPDATE_EST__condition__IF_1_0", "assign", "IF_1", Any["TOTAL_RAIN"], Any[(type = "lambda", name = "UPDATE_EST__lambda__IF_1_0", reference = 5)])
#
# Main.GrfnMod.Assignment{Array{Any,1},Array{Any,1}}("UPDATE_EST__assign__YIELD_EST_0", "assign", "YIELD_EST", Any["TOTAL_RAIN"], Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_0", reference = 6)])
#
# Main.GrfnMod.Assignment{Array{Any,1},Array{Any,1}}("UPDATE_EST__assign__YIELD_EST_1", "assign", "YIELD_EST", Any["TOTAL_RAIN"], Any[(type = "lambda", name = "UPDATE_EST__lambda__YIELD_EST_1", reference = 8)])
#
# Main.GrfnMod.Assignment{Array{Any,1},DataType}("UPDATE_EST__decision__YIELD_EST_0", "assign", "YIELD_EST", Any["IF_1_0", "YIELD_EST_2", "YIELD_EST_1"], Missing)
#
# Main.GrfnMod.Container{Array{Any,1},Array{Any,1},Array{Any,1}}("UPDATE_EST", "container", Any[(name = "RAIN", domain = "real"), (name = "TOTAL_RAIN", domain = "real"), (name = "YIELD_EST", domain = "real")], Any[(name = "TOTAL_RAIN", domain = "real"), (name = "RAIN", domain = "real"), (name = "IF_1", domain = "boolean"), (name = "YIELD_EST", domain = "real")], Any[(name = "UPDATE_EST__assign__TOTAL_RAIN_0", output = (variable = "TOTAL_RAIN", index = 1), input = Any[(variable = "TOTAL_RAIN", index = 0), (variable = "RAIN", index = 0)]), (name = "UPDATE_EST__condition__IF_1_0", output = (variable = "IF_1", index = 0), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__assign__YIELD_EST_0", output = (variable = "YIELD_EST", index = 1), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__assign__YIELD_EST_1", output = (variable = "YIELD_EST", index = 2), input = Any[(variable = "TOTAL_RAIN", index = 1)]), (name = "UPDATE_EST__decision__YIELD_EST_0", output = (variable = "YIELD_EST", index = 3), input = Any[(variable = "IF_1", index = 0), (variable = "YIELD_EST", index = 2), (variable = "YIELD_EST", index = 1)])])
#
# Main.GrfnMod.Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__MAX_RAIN_0", "assign", "MAX_RAIN", Any[], (type = "literal", dtype = "real", value = "4.0"))
#
# Main.GrfnMod.Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__CONSISTENCY_0", "assign", "CONSISTENCY", Any[], (type = "literal", dtype = "real", value = "64.0"))
#
# Main.GrfnMod.Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__ABSORPTION_0", "assign", "ABSORPTION", Any[], (type = "literal", dtype = "real", value = "0.6"))
#
# Main.GrfnMod.Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__YIELD_EST_0", "assign", "YIELD_EST", Any[], (type = "literal", dtype = "integer", value = "0"))
#
# Main.GrfnMod.Assignment{Array{Any,1},NamedTuple{(:type, :dtype, :value),Tuple{String,String,String}}}("CROP_YIELD__assign__TOTAL_RAIN_0", "assign", "TOTAL_RAIN", Any[], (type = "literal", dtype = "integer", value = "0"))
#
# Main.GrfnMod.Assignment{Array{Any,1},Array{Any,1}}("CROP_YIELD__assign__RAIN_0", "assign", "RAIN", Any["DAY", "CONSISTENCY", "MAX_RAIN", "ABSORPTION"], Any[(type = "lambda", name = "CROP_YIELD__lambda__RAIN_0", reference = 24)])
#
# Main.GrfnMod.LoopPlate{Array{Any,1},String,NamedTuple{(:start, :end),Tuple{NamedTuple{(:type, :dtype, :value),Tuple{String,String,Int64}},NamedTuple{(:value, :dtype, :type),Tuple{Int64,String,String}}}},Array{Any,1}}("CROP_YIELD__loop_plate__DAY_0", "loop_plate", Any["CONSISTENCY", "MAX_RAIN", "ABSORPTION", "RAIN", "TOTAL_RAIN", "YIELD_EST"], "DAY", (start = (type = "literal", dtype = "integer", value = 1), end = (value = 32, dtype = "integer", type = "literal")), Any[(name = "CROP_YIELD__assign__RAIN_0", output = (variable = "RAIN", index = 0), input = Any[(variable = "DAY", index = -1), (variable = "CONSISTENCY", index = -1), (variable = "MAX_RAIN", index = -1), (variable = "ABSORPTION", index = -1)]), (function = "UPDATE_EST", output = NamedTuple(), input = Any[(variable = "RAIN", index = 0), (variable = "TOTAL_RAIN", index = -1), (variable = "YIELD_EST", index = -1)]), (function = "print", output = NamedTuple(), input = Any[(variable = "DAY", index = -1), (variable = "YIELD_EST", index = -1)])])
#
# Main.GrfnMod.Container{Array{Any,1},Array{Any,1},Array{Any,1}}("CROP_YIELD", "container", Any[], Any[(name = "DAY", domain = "integer"), (name = "RAIN", domain = "real"), (name = "YIELD_EST", domain = "real"), (name = "TOTAL_RAIN", domain = "real"), (name = "MAX_RAIN", domain = "real"), (name = "CONSISTENCY", domain = "real"), (name = "ABSORPTION", domain = "real")], Any[(name = "CROP_YIELD__assign__MAX_RAIN_0", output = (variable = "MAX_RAIN", index = 2), input = Any[]), (name = "CROP_YIELD__assign__CONSISTENCY_0", output = (variable = "CONSISTENCY", index = 2), input = Any[]), (name = "CROP_YIELD__assign__ABSORPTION_0", output = (variable = "ABSORPTION", index = 2), input = Any[]), (name = "CROP_YIELD__assign__YIELD_EST_0", output = (variable = "YIELD_EST", index = 2), input = Any[]), (name = "CROP_YIELD__assign__TOTAL_RAIN_0", output = (variable = "TOTAL_RAIN", index = 2), input = Any[]), (name = "CROP_YIELD__loop_plate__DAY_0", inputs = Any["CONSISTENCY", "MAX_RAIN", "ABSORPTION", "RAIN", "TOTAL_RAIN", "YIELD_EST"], output = NamedTuple()), (function = "print", output = NamedTuple(), input = Any[(variable = "YIELD_EST", index = 2)])])
